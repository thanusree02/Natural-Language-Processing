# %% [markdown]
# <a href="https://colab.research.google.com/github/thanusree02/Natural-Language-Processing/blob/main/NLP%20LAB-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk spacy

# %%
import nltk
import spacy

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
text = """
Natural Language Processing (NLP) is a field of artificial intelligence
that helps computers understand, interpret, and generate human language.
It is widely used in chatbots, search engines, and voice assistants.
"""

# %%
words = text.split()
word_count = len(words)
print("Numbers of words:", word_count)
# Out:
# Numbers of words: 30

# %%
lower_text = text.lower()
print("lowercase text: \n")
print(lower_text)
# Out:
# lowercase text:
#
#
# natural language processing (nlp) is a field of artificial intelligence
# that helps computers understand, interpret, and generate human language.
# it is widely used in chatbots, search engines, and voice assistants.
